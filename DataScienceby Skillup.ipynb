# %% [markdown]
# # what is Data science:
# find unseen pattern in the data
# # Data Discovery
# Dat discovery involves asking the right questions,identifying the business problems,finding the best solution and gathering correct data from relevant sources for analysis.
# # Data preparation
# Data preparation deals with cleaning the data, finding the inconsistencies, tackling missing values, converting it into the right format and making it ready for analysis
# # Exploratory Data nalysis
# Analyze and visualize the data using different charts and graphs to find significant patterns and hidden treds that helps to understand the data better
# # Data Modeling
# Use classification, regression and clustering algorithms to build machine learning that can help predict and forecast furture trends.
# # Interpret the Results
# Validate the model results, draw the final conclusion and check if the performance of the model is in line with the requirements.
# # Data science Components:
# 1 Mathematic
# 2 statistic
# 3 Domain Expertise
# 4 Data Engineering
# 5 Data visualization
# 6 Machine learning
# # Tools in Data science
# 1 Python
# 2 Sas
# 3 Matlab
# 4 R
# 5 Apache spark
# 6 Tableau
# # Applications
# inter search
# voice assistants
# healthcare
# logistics
# E-commerce
# Robotics
# # Solving problems with Data Science
# 1 possible quest                  Desired Algorithms
# How much or how many?             Regression
# is it A or B                      classification
# How is this organized?            clustering
# How different is this?            Anomaly detection
# what to do next?                  Reinforment Learning
# # Algorithms used in Data Science
#  linear Regression
#  logistic regression
#  Decision tree
#  K nearest neighbors
#  K Means Clustering
#  Hierarchical Clustering
#  DBSCAN
#  Principal component analysis
# # Prerequisites for Dat Scienc
#  The following are the 3 essential traits of a data scientis
#  1 Curiosity
#      Asking the question
#  2 Common sense
#       To identify new ways to solve a business problem and to detect priority problems
#   3 Communication Skills:
#   requires
#   1 Machine learning
#       Machine learning is the backbone of Data Science. It is one of the many ways that Data Science uses to find solution to a problem.
#   2 Modeling Mathematical
#   3 Statistics
#     core foundation of data science
#   4 Computer programming
#   5 Data Bases
# # Tools and skills used in Data science
#  ## 2 Data analysis
#  skill: R Python, Stat
#  Tools: SAS, JUPTER, R Studio, MATLAB
#  ## 2 Data Warehousing:
#  skills: ETL, SQL Hadoop, Apache Spark
#  Tools: Infomatica/Talent, AWS Redshift
#  ## 3 Data Visualization
#  Skills: R, Python libraries
#  Tool: Jupter, Tableau, Cognos,RAW
#  ## 4 Macine Learning:
#  Skills: Algerbra, Algorithms, Statistics
#  Tools: Spark Mlib, Mathout, Azure ML studio
# # What Does a Data Scientist do?
#  Real world: Raw data => Process and Analyze=> meaningful Data =>useful insights
# # Must Know Machine Learning Algorithms:
#  The most basic and important techniques that you should know as a Data scientist are:
#  Regression => clustering => Decision tree=> Support vertor machine=> Naive Baiyes
#  # Life cycle
#  # 1 concept study
#    Understanding the problem statement, thorough study of the business model is required.
#    what is the use case?
#    What are the various specificaton?
#    What is the budget?
#    What is the end goal?
#    Concept of task?
#         Predict the price of 1.35 carat diamond
#         Get to know about the diamond industry, various terminologies used. Understand the business problem and collect Releveant and enough data.
#         Suppose we get the price of  diamond from different diamond retailers. But we want to find out the price of 1.35 carat diamond.
#  # 2 Data preparation:
#      Also known as data muging, it is the most important aspect of Data science lifecyle for any valuable insights to pop up.
#      i Data Interation:
#       Resolving any conflict in the data and handling redundancies
#      ii Data Transformation:
#        It involves normalization transformation and aggregation of data using ETL methods.
#      iii Data Reduction:
#        Using various strategies, reducing the size of the data but yielding the same outcome.
#       iv Data Cleaning:
#       correcting inconsistent data by filling out missing values and smoothing out noisy data.
# ## Ways to fill missing data value:
#      if dataset is huge, we can simply remove data rows with missing data values. It is the quikest way. i.e. we use the rest of  the  to predict the values
#      We can substiude missing values with mean of rest of the data using pandas dataframe in python.
#      i.e. df.mean()
#      df.fillna(mean)
#      Split the data into train data and test data in the ratio of 80:20
#      it is generally advised to divide the dataset into two random partition
#  # 3 Model Planning
#    The step involves Eploratory Data Analysis to understand the relation between variables and to see what the data can tell us.
#    Key variables are selected.
#   Deepre analysis of dataset to better understand the data
#   Goals: Know the data types and answer question with the data
#   uderstand how data is distributed
#   identify outliers
#   identify patterns, if any
#    #### Techniques
#    1 Histogram                2  Trend Analysis
#  ## Train Data vs Test Data
#  train data  is used  to develop model.
#  test data is used to validate model.
#   Tools: R, sas Matlab, Python
# # 4 Model Building
#  Using various  analytical toos and techniques, data is tranformed with the  goal of discovering useful infomation to build the righ model.
# # 5 Communicate resuls
# keys finding are identified and conveyed to the stakeholders
# A good data scientist should be able to communicate his findings with the business team such that it easily goes into execution phase.
# # 6 Operationalize
# final report code, and technical document are  delivered by the team.
# # Demand for Data Scientist:
# Industries with high demand of data scientist.
# Technology
# marketing
# Gaming
# Finance  eg bank
# Healthcare
# # Lesson 3
# # Top 5 Python Libraries For Data Science
# => Tensorflow:
#  Library for high performance Numerical computation
#  commits: 35,995
#  contributor: 1535
#  Used across many scientific domains
#  Data si tensorflow are represented as tensor, which are multidimensional arrays.
# * Features of TensorFlow*
# i) Better computation graph visualization
# ii) In neural Machine tanslation reduces error by 50-60%
# ii) Parallel computing to Execute complex models
# iv) seamsless library
# Application:
# i) Speech and recognition
# ii) text based application
# iii) Time series
# iv) Video detection
# => Numpy:
#  Stands for numerical python
#  commits: 18302
#  contributors: 658
# General purpose Array processing package
# Numpy is the fundamental package for numerical computation with python, it contains a powerful N-dimensional array object.
# * Features *
# Provides fast precompiled functions for numerical routines
# Array oriented computing for better efficiecy approach
# Compact & faster computataions with vectorization
# * Application*
# Extesively used in Data analysis
# creating powerful N-dimensional array
# forms the base of other libraries
# => Scipy:
#  Stands for scientific python
#  commits: 19498
#  contributors: 623

# %%
import scipy

# %%
from scipy import constants

# %%
print(constants.c)
print(constants.h)
print(constants.N_A)
# Out:
# 299792458.0
# 6.62607015e-34
# 6.02214076e+23

# %% [markdown]
# # 4 Pandas
# Stands for python data analysis library
# commits: 17428
# contributors: 1212
# used for data analysis & cleaning
# It provides fast flexibale, and expresive data structures designed to work with structured data easily and intuitively.
# Features
# Eloquent syntax & rich functionality
# Apply() enables you to run a function across a series of data
# High level abstraction
# contrains high level data strucures & manipulation tools.
# Application:
# General data wrangling
# ETL jobs and data storage
# Used in a wide variety of academic and commercial domains including statistic ETC
# Time series specific functionality

# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame(np.random.randn(6,4),index=list(range(6)), columns =list("ABCD"))
data
# Out:
#           A         B         C         D
# 0 -1.793037 -1.459751  0.795856 -0.895931
# 1 -1.170912  0.904890  0.632709 -2.305132
# 2 -0.373871 -0.457598  1.258111 -0.050899
# 3 -1.617726  0.247808 -0.781574 -0.702817
# 4 -1.005580 -0.362763 -1.029618 -1.830727
# 5 -0.549808 -0.018562  0.523639 -0.308479

# %%
data.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -1.085156 -0.190996  0.233187 -1.015664
# std    0.564081  0.791652  0.920376  0.879789
# min   -1.793037 -1.459751 -1.029618 -2.305132
# 25%   -1.506023 -0.433889 -0.455271 -1.597028
# 50%   -1.088246 -0.190662  0.578174 -0.799374
# 75%   -0.663751  0.181215  0.755070 -0.407064
# max   -0.373871  0.904890  1.258111 -0.050899

# %% [markdown]
# # Matplotlib
# Plotting library for pyton
# it provide and object oriented API for embedding plots into application.
# Features
# As usable as matlab with an advantage of being free and open source.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
np.random.seed(10)

# %%
N = 30
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30*np.random.rand(N))**3

# %%
plt.scatter(x,y, s=area, c = colors, alpha=0.4)
plt.show()
