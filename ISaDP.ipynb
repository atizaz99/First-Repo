# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00    61211.0            4
# 1                 45  2015-08-14 17:20:14-07:00    62414.0            4
# 2                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 3                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 4                 44  2015-08-14 17:40:16-07:00    63616.0            4
# ...              ...                        ...        ...          ...
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        is_weekend  is_holiday  temperature  is_start_of_semester  \
# ...

# %% [markdown]
# # Understanding Data
# ## head
# ## tail
# ## shape
# ## columns

# %%
df.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00    61211.0            4
# 1             45  2015-08-14 17:20:14-07:00    62414.0            4
# 2             40  2015-08-14 17:30:15-07:00    63015.0            4
# 3             40  2015-08-14 17:30:15-07:00    63015.0            4
# 4             44  2015-08-14 17:40:16-07:00    63616.0            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...

# %%
df.tail()
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        is_weekend  is_holiday  temperature  is_start_of_semester  \
# 62183           1           0        61.07                     0
# 62184           1           0        61.07                     0
# 62185           1           0        56.71                     0
# 62186           1           0        56.71                     0
# 62187           1           0        56.71                     0
#
#        is_during_semester  month  hour
# 62183                   1      3    18
# 62184                   1      3    18
# ...

# %%
df.shape
# Out:
# (62188, 11)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00    61211.0            4
# 1                 45  2015-08-14 17:20:14-07:00    62414.0            4
# 2                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 3                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 4                 44  2015-08-14 17:40:16-07:00    63616.0            4
# ...              ...                        ...        ...          ...
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        is_weekend  is_holiday  temperature  is_start_of_semester  \
# ...

# %%
df.columns
# Out:
# Index(['number_people', 'date', 'timestamp', 'day_of_week', 'is_weekend',
#        'is_holiday', 'temperature', 'is_start_of_semester',
#        'is_during_semester', 'month', 'hour'],
#       dtype='object')

# %% [markdown]
# # Data Preparation
#
# ### Droping duplicated columns and rows
# ## identifying duplicated columns

# %%
df = df[['number_people', 'date', 'timestamp', 'day_of_week', 
          #'is_weekend',
       #'is_holiday',
          'temperature', 
          #is_start_of_semester',
       'is_during_semester', 'month', 'hour']].copy()
df
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00    61211.0            4
# 1                 45  2015-08-14 17:20:14-07:00    62414.0            4
# 2                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 3                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 4                 44  2015-08-14 17:40:16-07:00    63616.0            4
# ...              ...                        ...        ...          ...
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        temperature  is_during_semester  month  hour
# ...

# %%
df.isna().sum()
# Out:
# number_people         0
# date                  0
# timestamp             1
# day_of_week           0
# temperature           0
# is_during_semester    0
# month                 0
# hour                  0
# dtype: int64

# %%
df.fillna(0).copy
# Out:
# <bound method NDFrame.copy of        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00    61211.0            4
# 1                 45  2015-08-14 17:20:14-07:00    62414.0            4
# 2                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 3                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 4                 44  2015-08-14 17:40:16-07:00    63616.0            4
# ...              ...                        ...        ...          ...
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        temperature  is_during_semester  month  hour
# ...

# %%
df.isnull()
# Out:
#        number_people   date  timestamp  day_of_week  temperature  \
# 0              False  False      False        False        False
# 1              False  False      False        False        False
# 2              False  False      False        False        False
# 3              False  False      False        False        False
# 4              False  False      False        False        False
# ...              ...    ...        ...          ...          ...
# 62183          False  False      False        False        False
# 62184          False  False      False        False        False
# 62185          False  False      False        False        False
# 62186          False  False      False        False        False
# 62187          False  False      False        False        False
#
#        is_during_semester  month   hour
# 0                   False  False  False
# 1                   False  False  False
# 2                   False  False  False
# ...

# %%
df.loc[df.duplicated()]
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 3                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 6                 45  2015-08-14 17:50:17-07:00    64217.0            4
# 28206             13  2016-05-23 07:35:33-07:00    27333.0            0
# 28208             15  2016-05-23 07:45:39-07:00    27939.0            0
#
#        temperature  is_during_semester  month  hour
# 3            71.76                   0      8    17
# 6            71.76                   0      8    17
# 28206        56.33                   0      5     7
# 28208        56.33                   0      5     7

# %%
df1 =df.drop_duplicates().copy()

# %% [markdown]
# # Understaing Features
# ## Ploting features distribution

# %%
df1
# Out:
#        number_people                       date  timestamp  day_of_week  \
# 0                 37  2015-08-14 17:00:11-07:00    61211.0            4
# 1                 45  2015-08-14 17:20:14-07:00    62414.0            4
# 2                 40  2015-08-14 17:30:15-07:00    63015.0            4
# 4                 44  2015-08-14 17:40:16-07:00    63616.0            4
# 5                 45  2015-08-14 17:50:17-07:00    64217.0            4
# ...              ...                        ...        ...          ...
# 62183             23  2017-03-18 18:42:28-07:00    67348.0            5
# 62184             21  2017-03-18 18:52:35-07:00    67955.0            5
# 62185             25  2017-03-18 19:02:40-07:00    68560.0            5
# 62186             18  2017-03-18 19:12:47-07:00    69167.0            5
# 62187             23  2017-03-18 19:22:51-07:00    69771.0            5
#
#        temperature  is_during_semester  month  hour
# ...

# %%
df1['date'].value_counts()
# Out:
# 2015-08-14 17:00:11-07:00    1
# 2016-08-26 09:21:15-07:00    1
# 2016-08-26 03:22:15-07:00    1
# 2016-08-26 03:32:16-07:00    1
# 2016-08-26 03:42:17-07:00    1
#                             ..
# 2016-03-14 11:40:15-07:00    1
# 2016-03-14 11:50:17-07:00    1
# 2016-03-14 12:00:18-07:00    1
# 2016-03-14 12:20:13-07:00    1
# 2017-03-18 19:22:51-07:00    1
# Name: date, Length: 62184, dtype: int64

# %%
df1['month'].value_counts() \
    .head(10)\
    .plot(kind = 'bar', title = 'Monthly Report', xlabel = 'Month')
# Out:
# <AxesSubplot:title={'center':'Monthly Report'}, xlabel='Month'>

# %%
df.plot(kind = 'hist', x = 'month', y = 'number_people')
plt.show()

# %% [markdown]
# # Feature Relation

# %%
df1.plot(kind ='scatter', x='month', y= 'number_people', title = 'Number people vs month')
plt.show()

# %%
sn = sns.scatterplot(x='hour', y = 'temperature', data = df1, hue = 'temperature')
plt.show()

# %%
df1.columns
# Out:
# Index(['number_people', 'date', 'timestamp', 'day_of_week', 'temperature',
#        'is_during_semester', 'month', 'hour'],
#       dtype='object')

# %%
#sn = sns.pairplot(df1,vars =['number_people', 'date', 'timestamp', 'day_of_week', 'temperature',
   #    'is_during_semester', 'month', 'hour'],)
#plt.show()
